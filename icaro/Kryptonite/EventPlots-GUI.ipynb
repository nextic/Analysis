# %% [markdown]
# # EVENT PLOTS -- GUI version

# %% [markdown]
# A NB template to produce event plots (GUI version)

# %%
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2017-04-05 16:57:38

# %%
# %gui qt
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import time
import tables as tb
import numpy as np

# %%
from invisible_cities.database import load_db

# %%
import invisible_cities.reco.tbl_functions as tbl
import invisible_cities.reco.wfm_functions as wfm
import invisible_cities.sierpe.blr as blr
import invisible_cities.reco.peak_functions_c as cpf
from invisible_cities.core.mpl_functions import set_plot_labels
from invisible_cities.reco.params import S12Params, ThresholdParams
from   invisible_cities.core.system_of_units_c import units

# %%
from gui_functions import fplot_pmt_waveforms, fplot_pmt_signals_vs_time_mus, fplot_signal_vs_time_mus,\
                           fplot_s12, hist_1d

# %%
from event_pmaps import EventPmaps, print_s12, print_s2si

# %%
run_number = 3389

# %%
DataPMT = load_db.DataPMT(run_number)

# %%
DataPMT
# Out:
#     SensorID  ChannelID PmtID  Active         X         Y  coeff_blr  \
# 0          0         22  PMT1       1  -23.9414   65.7785    0.00080
# 1          1         18  PMT3       1  -44.9951  -53.6231    0.00080
# 2          2         23  PMT2       1   68.9365  -12.1554    0.00080
# 3          3          0  PMT4       1    0.0000  185.0000    0.00161
# 4          4         31  PMTC       1 -118.9160  141.7180    0.00160
# 5          5          8  PMTB       1 -182.1890   32.1249    0.00161
# 6          6          5  PMTA       1 -160.2150  -92.5000    0.00161
# 7          7          4  PMT9       1  -63.2737 -173.8430    0.00161
# 8          8          1  PMT8       1   63.2737 -173.8430    0.00162
# 9         10         27  PMT6       1  182.1890   32.1249    0.00080
# 10        11         26  PMT5       1  118.9160  141.7180    0.00080
# 11         9         30  PMT7       0  160.2150  -92.5000    0.00000
#
#      coeff_c  adc_to_pes  noise_rms   Sigma
# 0   0.000001       25.39     0.7160   9.474
# 1   0.000001       26.49     0.8744  10.510
# 2   0.000001       27.74     0.7303   9.031
# 3   0.000003       25.17     0.7060   8.720
# 4   0.000003       26.56     0.7000   8.910
# 5   0.000003       21.55     0.7278   6.900
# 6   0.000003       23.86     0.7323   7.860
# 7   0.000003       33.57     0.7206  11.750
# 8   0.000003       22.15     0.7213   7.070
# 9   0.000001       20.83     0.7921   6.780
# 10  0.000001       23.78     0.8660   8.050
# 11  0.000000        0.00     0.0000   0.000

# %%
from PyQt5 import QtCore, QtWidgets, uic
from matplotlib.backends.backend_qt5agg import (
    FigureCanvasQTAgg as FigureCanvas,
    NavigationToolbar2QT as NavigationToolbar)
from matplotlib.figure import Figure

from PyQt5.uic import loadUiType


qtCreatorFile = "event_maps.ui" # Enter file here.
Ui_MainWindow, QMainWindow = loadUiType(qtCreatorFile)

# %%
class QtGui(QMainWindow, Ui_MainWindow):
    def __init__(self, ):
        super(QtGui, self).__init__()
        self.setupUi(self)
        
        self.fig_dict = {}
        self.mplfigs.itemClicked.connect(self.change_figure)

        fig = Figure()
        self.add_mpl(fig)

    def add_figure(self, name, fig):
        test_key = self.fig_dict.pop(name, None)
        self.fig_dict[name] = fig
        if not test_key: # key not in dict
            self.mplfigs.addItem(name)

    def change_figure(self, item):
        text = item.text()
        self.rm_mpl()
        self.add_mpl(self.fig_dict[text])

    def add_mpl(self, fig):
        self.canvas = FigureCanvas(fig)
        self.mplvl.addWidget(self.canvas)
        self.canvas.draw()
        self.toolbar = NavigationToolbar(self.canvas,
                self.mplwindow, coordinates=True)
        self.mplvl.addWidget(self.toolbar)

    def rm_mpl(self,):
        self.mplvl.removeWidget(self.canvas)
        self.canvas.close()
        self.mplvl.removeWidget(self.toolbar)
        self.toolbar.close()

# %%
def scan_events(epm, gui, pmtrwf, sipmrwf, 
                event_list=list(range(1)), 
                event_plot_list=list(range(1)), 
                printout=10):
    """Loop over events"""
    
    for event in event_list:
        if(event%printout == 0):
            print('processing event number {}'.format(event))
        epm.calibrated_pmt_and_csum(event, pmtrwf)
        epm.calibrated_sipm(event, sipmrwf)
        epm.find_s1()
        epm.find_s2()
        if (len(epm.S2) > 0):
            epm.find_s2si()
        
        if event in event_plot_list:
            #gui.add_figure('RWF-event-{}'.format(event), 
            #                plot_pmt_waveforms(epm.RWF, zoom=False, window_size=10000))
            gui.add_figure('CWF_vs_time_mus-event-{}'.format(event), 
                            fplot_pmt_signals_vs_time_mus(epm.CWF,
                                                         epm.P.pmt_active,
                                                         t_min      =    0,
                                                         t_max      = 1300,
                                                         signal_min =    -5,
                                                         signal_max =  200))
            gui.add_figure('Calibrated_SUM-event-{}'.format(event), 
                            fplot_signal_vs_time_mus(epm.csum, t_min=0, t_max=1300, signal_min=-5, signal_max=100))
            if (len(epm.S1) > 0):
                gui.add_figure('S1-event-{}'.format(event), fplot_s12(epm.S1))
            if (len(epm.S2) > 0):
                gui.add_figure('S2-event-{}'.format(event), fplot_s12(epm.S2))

# %%
RWF_file = os.path.join(os.environ['IC_DATA'],'LSC/wvfms/3389/dst_waves.gdcsnext.000_3389.root.h5')

# %%
h5rwf = tb.open_file(RWF_file,'r')

# %%
pmtrwf, pmtblr, sipmrwf = tbl.get_vectors(h5rwf)

# %%
NEVT, NPMT, PMTWL = pmtrwf.shape
NEVT, NSIPM, SIPMWL = sipmrwf.shape
print("""
        Number of events in file = {}
        Number of PMTs = {}
        PMTWL = {}
        Number of SiPMs = {}
        SiPMWL = {}
      """.format(NEVT, NPMT, PMTWL,NSIPM, SIPMWL))
# Out:
#         Number of events in file = 163
#         Number of PMTs = 12
#         PMTWL = 52000
#         Number of SiPMs = 1792
#         SiPMWL = 1300

# %%
s1par  = S12Params(tmin=0*units.mus, tmax=640*units.mus, lmin=5, lmax=20, stride=4, rebin=False)
s2par = S12Params(tmin=640*units.mus, tmax=800*units.mus, stride=40, lmin=80, lmax=20000, rebin=True)
thr    = ThresholdParams(thr_s1=0.5 * units.pes,  thr_s2=1 *units.pes,
                        thr_MAU = 3 * units.adc, thr_sipm = 3.5 * units.pes,
                        thr_SIPM = 30 * units.adc)

# %%
gui=QtGui()
gui.show()

# %%
epm = EventPmaps(run_number, s1par, s2par, thr, verbose=True)

# %%
event=0
epm.calibrated_pmt_and_csum(event, pmtrwf)
# Out:
# 7477.3421116275758

# %%
gui.add_figure('CWF-event-{}'.format(event), 
                fplot_pmt_signals_vs_time_mus(epm.CWF,
                                             epm.P.pmt_active,
                                             t_min      =    0,
                                             t_max      = 1300,
                                             signal_min =    -5,
                                             signal_max =  250))

# %%
gui.add_figure('PMTs-event-{}'.format(event), 
                fplot_pmt_signals_vs_time_mus(epm.CAL_PMT,
                                             epm.P.pmt_active,
                                             t_min      =    0,
                                             t_max      = 1300,
                                             signal_min =    -5,
                                             signal_max =  10))

# %%
n_events = 160
sample_plot = 10
t0 = time.time()
scan_events(epm, gui, pmtrwf, sipmrwf, 
            event_list=list(range(n_events)), 
            event_plot_list=list(range(0,n_events,sample_plot)),
           printout=10)
t1 = time.time()        
dt = t1 - t0
print("run {} events in {} s event/s = {}".format(n_events, dt, dt/n_events))
# Out:
# processing event number 0
# number of peaks = 1
# S12 number = 0, samples = 17 sum in pes =58.61823131191956
# time vector (mus) = [ 381.675  381.7    381.725  381.75   381.775  381.8    381.825  381.85
#   381.875  381.9    381.925  381.95   381.975  382.     382.075  382.1
#   382.125]
# energy vector (pes) = [ 1.61917637  4.26629217  7.76816226  9.1865877   8.86180842  7.24039865
#   5.02407006  3.78509372  2.95172416  1.79096222  1.56561245  1.40410572
#   0.902514    0.53159509  0.54448564  0.67117998  0.50446272]
# number of peaks = 1
# S12 number = 0, samples = 12 sum in pes =7002.0556670851765
# time vector (mus) = [ 648.611875    649.6875      650.6875      651.6875      652.6875
#   653.6875      654.6875      655.6875      656.6875      657.6875
#   658.6925      659.72142857]
# energy vector (pes) = [   92.34185897   305.01491887   609.24077745   986.05036791  1146.15608197
#   1197.89848084  1079.29428206   699.55456278   539.60781327   262.37786222
#     76.06448758     8.45417316]
# S2Si for peak number = 0
# sipm number = 980, energy = 50.006843604962235
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =7.0429711491779035
# time vector (mus) = [ 486.325  486.35   486.375  486.4    486.425  486.45   486.475  486.5  ]
# energy vector (pes) = [ 1.00572392  1.42807619  1.39077321  0.71169641  0.55596226  0.58390724
#   0.71341985  0.65341206]
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =4310.023342412648
# time vector (mus) = [ 648.969375  650.0125    651.0125    652.0125    653.0125    654.0125
#   655.0125    656.018125  657.175     658.4     ]
# energy vector (pes) = [   79.10731397   225.66393013   579.11896605   848.53140956  1040.56168527
#    821.1740507    424.45342996   209.32054645    78.80667266     3.28533765]
# S2Si for peak number = 0
# sipm number = 1677, energy = 43.34304790296307
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =10.06058866579143
# time vector (mus) = [ 560.675  560.7    560.725  560.75   560.775  560.8    560.825  560.85
#   560.875  560.9  ]
# energy vector (pes) = [ 0.84893146  1.32635039  1.54025639  1.70296851  1.44951232  0.80352272
#   0.6222865   0.62544253  0.62955583  0.51176201]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =5998.549626354456
# time vector (mus) = [ 649.65125     650.6625      651.6625      652.6625      653.6625
#   654.6625      655.65428571]
# energy vector (pes) = [  155.58696218   567.92918747  1352.22258818  1844.07750461  1357.22038376
#    585.98580281   135.52719735]
# S2Si for peak number = 0
# sipm number = 386, energy = 33.281227160643894
# sipm number = 393, energy = 75.86132412207081
# sipm number = 394, energy = 48.77369537010665
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =9.029172133120799
# time vector (mus) = [ 549.95   549.975  550.     550.025  550.05   550.075  550.1  ]
# energy vector (pes) = [ 0.79413851  1.59442488  2.14860128  1.88534027  1.22456531  0.69365962
#   0.68844227]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =5904.074327884989
# time vector (mus) = [ 649.68125    650.6875     651.6875     652.6875     653.6875     654.6875
#   655.7025641]
# energy vector (pes) = [  125.19195543   496.02481193  1302.19767758  1819.04647729  1458.41380528
#    552.0093494    151.19025097]
# S2Si for peak number = 0
# sipm number = 364, energy = 47.525253190910846
# sipm number = 365, energy = 31.08545417255708
# sipm number = 373, energy = 43.07832740242921
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =8.57810779057384
# time vector (mus) = [ 526.45   526.475  526.5    526.525  526.55   526.575]
# energy vector (pes) = [ 0.97608253  1.25054792  2.0015297   1.97308892  1.36213136  1.01472736]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =6396.546483613141
# time vector (mus) = [ 649.175   650.1875  651.1875  652.1875  653.1875  654.1875  655.1875
#   656.1975  657.025 ]
# energy vector (pes) = [  102.61213846   355.35916069   973.41816035  1638.03791279  1760.12440897
#   1004.69782556   436.84906732   113.93539943    11.51241004]
# S2Si for peak number = 0
# sipm number = 1438, energy = 49.78261805346304
# sipm number = 1446, energy = 69.5017863036403
# sipm number = 1447, energy = 34.44073482145929
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =9.487766359965406
# time vector (mus) = [ 492.125  492.15   492.175  492.2    492.225  492.25   492.35   492.375
#   492.4    492.425]
# energy vector (pes) = [ 0.95258665  1.27021607  1.3335397   1.1432868   0.88521082  0.9096625
#   0.61561285  0.88549707  0.83829167  0.65386224]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4470.354191574498
# time vector (mus) = [ 648.59875     649.7125      650.7125      651.7125      652.7125
#   653.7125      654.7125      655.719375    656.80606061]
# energy vector (pes) = [   73.04784967   204.63763415   633.11921458  1006.91769553  1114.18964187
#    801.08934276   407.87403108   159.71401432    69.76476762]
# S2Si for peak number = 0
# sipm number = 359, energy = 48.6579536166313
# sipm number = 367, energy = 36.42228389646131
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6047.124932392124
# time vector (mus) = [ 649.53125     650.5375      651.5375      652.5375      653.5375
#   654.5375      655.61081081]
# energy vector (pes) = [  134.36454093   486.05798834  1497.61647422  1886.40026467  1305.3508432
#    605.61049263   131.72432839]
# S2Si for peak number = 0
# sipm number = 181, energy = 62.81202832926971
# sipm number = 182, energy = 72.21286054363019
# number of peaks = 8
# S12 number = 0, samples = 17 sum in pes =14.915590336405149
# time vector (mus) = [ 96.775  96.8    96.825  96.85   96.875  96.9    96.925  96.95   96.975
#   97.     97.025  97.125  97.15   97.175  97.2    97.225  97.25 ]
# energy vector (pes) = [ 0.50751947  0.61261017  0.73837632  0.83137948  0.8112955   0.74237599
#   0.94235793  0.97349761  0.87407116  0.75524413  0.59964877  0.69449718
#   1.00854803  1.75271333  1.45275785  1.06567981  0.55301762]
# S12 number = 1, samples = 5 sum in pes =5.657661146118829
# time vector (mus) = [ 106.225  106.25   106.275  106.3    106.325]
# energy vector (pes) = [ 0.9546064   1.13044544  1.81651486  0.89750391  0.85859054]
# S12 number = 2, samples = 7 sum in pes =6.974618247992281
# time vector (mus) = [ 106.625  106.65   106.675  106.7    106.8    106.825  106.85 ]
# energy vector (pes) = [ 0.86906419  1.6168313   1.52574326  0.52487397  0.60553311  0.87985688
#   0.95271553]
# S12 number = 3, samples = 8 sum in pes =5.407394785571949
# time vector (mus) = [ 107.95   107.975  108.     108.025  108.05   108.075  108.175  108.2  ]
# energy vector (pes) = [ 0.58900751  0.8950595   0.9614753   0.77779947  0.55456021  0.55090071
#   0.5615149   0.5170772 ]
# S12 number = 4, samples = 5 sum in pes =3.856444109361688
# time vector (mus) = [ 234.8    234.825  234.85   234.875  234.9  ]
# energy vector (pes) = [ 0.54960456  0.91655735  0.86554107  0.92417872  0.60056241]
# S12 number = 5, samples = 10 sum in pes =58.86589568905458
# time vector (mus) = [ 394.35   394.375  394.4    394.425  394.45   394.475  394.5    394.525
#   394.55   394.6  ]
# energy vector (pes) = [  2.45703722   5.85757102   9.342368    11.05999223  10.67623288
#    8.44481759   5.41453644   3.28510645   1.590703     0.73753087]
# S12 number = 6, samples = 5 sum in pes =3.930173243053303
# time vector (mus) = [ 558.425  558.45   558.475  558.575  558.6  ]
# energy vector (pes) = [ 0.74019619  0.93918708  0.87937384  0.72220172  0.64921441]
# S12 number = 7, samples = 6 sum in pes =3.8898738367150387
# time vector (mus) = [ 631.15   631.175  631.2    631.225  631.3    631.325]
# energy vector (pes) = [ 0.59130447  0.827293    0.68034496  0.54180555  0.69178215  0.55734369]
# number of peaks = 1
# S12 number = 0, samples = 12 sum in pes =7046.400410546955
# time vector (mus) = [ 648.06375     649.1125      650.1125      651.1125      652.1125
#   653.1125      654.1125      655.1125      656.1125      657.1125
#   658.291875    659.52307692]
# energy vector (pes) = [   79.41003679   179.62133995   393.6927468    809.12207707  1100.478997
#   1526.16635772  1050.54692223   948.38752351   556.96784811   300.262696
#     79.74665518    21.99721019]
# S2Si for peak number = 0
# sipm number = 603, energy = 44.75199530550084
# sipm number = 610, energy = 33.587344709456715
# sipm number = 611, energy = 54.13577180425996
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =13.514516570259069
# time vector (mus) = [ 587.825  587.85   587.875  587.9    587.925  587.95   587.975  588.   ]
# energy vector (pes) = [ 0.8718545   1.99386409  2.83970663  2.95072889  2.32241482  1.52392851
#   0.50560587  0.50641326]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =8999.4304222288
# time vector (mus) = [ 649.399375    650.4125      651.4125      652.4125      653.4125
#   654.4125      655.38918919]
# energy vector (pes) = [  158.34397876   854.25207592  2253.44505926  2827.02284057  1910.63786311
#    817.69033859   178.03826601]
# S2Si for peak number = 0
# sipm number = 747, energy = 51.142747553234926
# sipm number = 754, energy = 48.00649568325407
# sipm number = 755, energy = 130.8406071512479
# sipm number = 763, energy = 50.37170681860108
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =15.372053912140041
# time vector (mus) = [ 216.9    216.925  216.95   216.975  217.     217.025]
# energy vector (pes) = [ 1.45834054  3.11860104  4.02788655  3.61979037  2.2690211   0.87841431]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7107.523864002991
# time vector (mus) = [ 649.4875      650.4875      651.4875      652.4875      653.4875
#   654.4875      655.53648649]
# energy vector (pes) = [  118.10303415   713.21562827  1802.25616752  2366.13634127  1440.10561228
#    547.5994401    120.10764042]
# S2Si for peak number = 0
# sipm number = 1474, energy = 30.564380115394755
# sipm number = 1481, energy = 47.615094077642524
# sipm number = 1482, energy = 97.25447741642074
# processing event number 10
# number of peaks = 1
# S12 number = 0, samples = 5 sum in pes =7.664277187691317
# time vector (mus) = [ 541.925  541.95   541.975  542.     542.025]
# energy vector (pes) = [ 0.79674009  1.49925866  2.16435314  2.16448901  1.03943629]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6672.422212885738
# time vector (mus) = [ 649.8375      650.8375      651.8375      652.8375      653.8375
#   654.8375      655.8375      656.53214286]
# energy vector (pes) = [  169.30217915   540.87190269  1472.23057742  1784.95634036  1562.66016491
#    836.28730847   291.06140748    15.05233239]
# S2Si for peak number = 0
# sipm number = 436, energy = 34.70743480021323
# sipm number = 444, energy = 78.40963538943113
# sipm number = 445, energy = 64.0184537205717
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =5021.739957150969
# time vector (mus) = [ 648.59625     649.8375      650.8375      651.8375      652.8375
#   653.8375      654.8375      655.8375      656.60441176]
# energy vector (pes) = [   72.67864841   278.86765883   727.08450952  1144.23453548  1226.70331008
#    882.57195224   502.58081149   156.95379026    30.06474085]
# S2Si for peak number = 0
# sipm number = 696, energy = 32.99966563059475
# sipm number = 1024, energy = 48.03745623843771
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =13.322993521946465
# time vector (mus) = [ 574.775  574.8    574.825  574.85   574.875  574.9  ]
# energy vector (pes) = [ 1.41567488  2.55899734  3.11297587  2.88694293  2.00539996  1.34300255]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =7757.4749222496575
# time vector (mus) = [ 649.76125  650.7875   651.7875   652.7875   653.7875   654.7875   655.8375
#   656.675  ]
# energy vector (pes) = [  126.17584769   662.05505537  1952.3281696   2746.29315491  1694.33825057
#    473.42563299    82.66737495    20.19143617]
# S2Si for peak number = 0
# sipm number = 976, energy = 52.96172224200745
# sipm number = 1047, energy = 122.15262558647949
# sipm number = 1055, energy = 44.78973081712808
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =10.739671139444159
# time vector (mus) = [ 527.95   527.975  528.     528.025  528.05   528.075  528.1    528.125
#   528.15 ]
# energy vector (pes) = [ 0.71024305  1.20780774  1.44061869  1.80298664  1.71394324  1.48264677
#   0.94598722  0.91079271  0.52464507]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4448.562332617028
# time vector (mus) = [ 648.5575   649.7875   650.7875   651.7875   652.7875   653.7875   654.7875
#   655.83375  656.64   ]
# energy vector (pes) = [   78.98326689   273.17407957   648.50929316  1010.45010691  1081.08118973
#    839.81471587   375.91270883   116.8402183     23.79675335]
# S2Si for peak number = 0
# sipm number = 1750, energy = 57.34907790833224
# sipm number = 1751, energy = 43.44002839689841
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6201.265005473748
# time vector (mus) = [ 649.758125  650.7875    651.7875    652.7875    653.7875    654.7875
#   655.8175    656.675   ]
# energy vector (pes) = [  119.65833005   512.78829904  1474.48329683  1914.37529137  1351.1373765
#    664.17223993   153.49228088    11.15789088]
# S2Si for peak number = 0
# sipm number = 1154, energy = 51.048010678486314
# sipm number = 1155, energy = 38.42779358046534
# sipm number = 1162, energy = 55.815228907252994
# sipm number = 1163, energy = 44.042452752459425
# number of peaks = 2
# S12 number = 0, samples = 9 sum in pes =14.699835312367478
# time vector (mus) = [ 582.075  582.1    582.125  582.15   582.175  582.2    582.275  582.3
#   582.325]
# energy vector (pes) = [ 1.16808134  2.05381171  2.94594549  3.00841385  2.23472283  1.52209863
#   0.58510736  0.62831042  0.55334369]
# S12 number = 1, samples = 5 sum in pes =4.358231165999657
# time vector (mus) = [ 582.55   582.6    582.625  582.65   582.675]
# energy vector (pes) = [ 0.50836823  0.90719686  1.1899283   1.15681528  0.5959225 ]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7637.386549651278
# time vector (mus) = [ 650.03     651.0375   652.0375   653.0375   654.0375   655.0375
#   655.84375]
# energy vector (pes) = [  224.69423162   931.87325199  2562.15598246  2575.81152424  1037.27526816
#    270.39316191    35.18312928]
# S2Si for peak number = 0
# sipm number = 684, energy = 66.6834635682274
# sipm number = 685, energy = 40.572110721480264
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =16.84530249762602
# time vector (mus) = [ 570.1    570.125  570.15   570.175  570.2    570.225  570.25   570.275
#   570.3  ]
# energy vector (pes) = [ 0.73726922  2.15939153  2.85609086  3.02076343  2.69381462  1.83977439
#   1.65500893  1.03897202  0.8442175 ]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =8058.7292093733795
# time vector (mus) = [ 649.64875     650.7375      651.7375      652.7375      653.7375
#   654.7375      655.63583333]
# energy vector (pes) = [  117.74318981   807.19350078  2070.2868895   2469.14272201  1879.84493501
#    588.65775373   125.86021852]
# S2Si for peak number = 0
# sipm number = 1100, energy = 33.100290734114445
# sipm number = 1101, energy = 41.562813350522845
# sipm number = 1108, energy = 73.063681145441
# sipm number = 1109, energy = 92.63202099239358
# number of peaks = 1
# S12 number = 0, samples = 11 sum in pes =12.398171861807315
# time vector (mus) = [ 548.875  548.9    548.925  548.95   548.975  549.     549.025  549.05
#   549.1    549.125  549.15 ]
# energy vector (pes) = [ 0.73279518  1.58658203  2.10397174  1.89756784  1.53968795  1.10352404
#   0.80853431  0.55149559  0.55852828  0.79074937  0.72473553]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6398.611097480698
# time vector (mus) = [ 649.3375  650.3375  651.3375  652.3375  653.3375  654.3375  655.3375
#   656.2125]
# energy vector (pes) = [   78.05189431   372.10555634   898.18653743  1771.57269956  1795.72436768
#   1025.43066748   376.91797583    80.62139885]
# S2Si for peak number = 0
# sipm number = 648, energy = 66.64512881526564
# sipm number = 719, energy = 57.51440370542382
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =3.744280673512697
# time vector (mus) = [ 502.75   502.8    502.85   502.875  502.9    502.925]
# energy vector (pes) = [ 0.51134006  0.57877243  0.57589904  0.85904549  0.59046721  0.62875644]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4891.106588690235
# time vector (mus) = [ 648.851875  649.8875    650.8875    651.8875    652.8875    653.8875
#   654.8875    655.8875    656.84375 ]
# energy vector (pes) = [   73.94462044   245.2764432    628.44059852  1054.03553309  1226.13302375
#   1028.26648524   477.98218434   127.95770513    29.06999499]
# S2Si for peak number = 0
# sipm number = 680, energy = 39.979646928155894
# number of peaks = 1
# S12 number = 0, samples = 17 sum in pes =18.61980615401423
# time vector (mus) = [ 565.975  566.     566.025  566.05   566.075  566.1    566.125  566.15
#   566.175  566.2    566.225  566.25   566.275  566.3    566.325  566.35
#   566.375]
# energy vector (pes) = [ 0.84568457  1.43131082  1.84633159  1.69214166  1.42760869  0.97024975
#   0.52319952  0.52622146  0.54054231  0.51111022  0.99581185  1.13497832
#   1.73133467  1.68948979  1.32990033  0.83922723  0.58466338]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7566.9182350050905
# time vector (mus) = [ 649.58125     650.5875      651.5875      652.5875      653.5875
#   654.5875      655.62371795]
# energy vector (pes) = [  149.14743115   664.78230823  1928.25352563  2513.95799605  1650.11316852
#    558.89775472   101.76605071]
# S2Si for peak number = 0
# sipm number = 757, energy = 33.71310692631035
# sipm number = 764, energy = 44.84746078825728
# sipm number = 765, energy = 88.46588030971851
# processing event number 20
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =5902.900481368797
# time vector (mus) = [ 649.39625  650.4375   651.4375   652.4375   653.4375   654.4375
#   655.45375  656.4625 ]
# energy vector (pes) = [   86.85780401   500.92175835  1321.87731553  1776.26318003  1397.04086662
#    625.83036798   168.75536863    25.35382022]
# S2Si for peak number = 0
# sipm number = 1514, energy = 44.44287366918278
# sipm number = 1521, energy = 39.38573639658346
# sipm number = 1522, energy = 71.3752360544564
# sipm number = 1530, energy = 35.890123970975196
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =8.901871241774005
# time vector (mus) = [ 456.875  456.9    456.925  456.95   456.975  457.   ]
# energy vector (pes) = [ 1.12366145  1.84832092  1.82777293  1.84485918  1.24524046  1.0120163 ]
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =4870.515229679611
# time vector (mus) = [ 648.78625   649.8375    650.8375    651.8375    652.8375    653.8375
#   654.8375    655.8375    656.841875  658.075   ]
# energy vector (pes) = [   77.88219989   249.35923156   628.97693565   905.037156    1060.17489731
#    922.36873891   587.53459791   297.58638255   128.01547194    13.57961796]
# S2Si for peak number = 0
# sipm number = 1425, energy = 30.881519787497368
# sipm number = 1426, energy = 32.87594324174392
# sipm number = 1434, energy = 41.1422693444094
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =7.908607106094154
# time vector (mus) = [ 617.175  617.2    617.225  617.25   617.275  617.3  ]
# energy vector (pes) = [ 0.86618051  1.526023    1.79287344  1.75738725  1.33530562  0.63083727]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6488.506322368314
# time vector (mus) = [ 650.1375  651.1375  652.1375  653.1375  654.1375  655.1375  655.8025]
# energy vector (pes) = [  304.83507068  1397.64159205  2344.3917971   1586.19594541   661.96709933
#    170.03761177    23.43720603]
# S2Si for peak number = 0
# sipm number = 1589, energy = 56.529337340225474
# sipm number = 1590, energy = 128.1602231674494
# sipm number = 1598, energy = 39.53817704191045
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =5.224082576908788
# time vector (mus) = [ 546.775  546.8    546.825  546.85   546.875  546.9  ]
# energy vector (pes) = [ 0.55013202  1.05833198  1.15656592  1.07851029  0.86950538  0.51103699]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6632.741580842847
# time vector (mus) = [ 649.5325      650.5375      651.5375      652.5375      653.5375
#   654.5375      655.5375      656.78703704]
# energy vector (pes) = [  120.65314027   447.88332507  1145.28907958  1916.24676745  1727.61216152
#    932.46074309   284.54702699    58.04933687]
# S2Si for peak number = 0
# sipm number = 1044, energy = 68.42659738050112
# sipm number = 1045, energy = 61.1852086414182
# sipm number = 1052, energy = 40.98216900881115
# number of peaks = 11
# S12 number = 0, samples = 5 sum in pes =4.066650188983624
# time vector (mus) = [ 233.25   233.275  233.3    233.325  233.35 ]
# energy vector (pes) = [ 0.82430994  1.00141076  0.8241802   0.86393145  0.55281784]
# S12 number = 1, samples = 5 sum in pes =3.5254203586531574
# time vector (mus) = [ 233.475  233.575  233.6    233.625  233.65 ]
# energy vector (pes) = [ 0.5224017   0.86680193  0.87994913  0.71886074  0.53740686]
# S12 number = 2, samples = 7 sum in pes =4.1745836451905465
# time vector (mus) = [ 234.025  234.05   234.1    234.2    234.225  234.25   234.275]
# energy vector (pes) = [ 0.56620596  0.60249349  0.5062328   0.57266769  0.73030947  0.69335695
#   0.50331729]
# S12 number = 3, samples = 8 sum in pes =6.332238360541444
# time vector (mus) = [ 234.75   234.775  234.8    234.825  234.85   234.875  234.9    234.925]
# energy vector (pes) = [ 0.5747972   1.08678499  0.93592315  0.59722231  0.74270992  1.07038507
#   0.8148181   0.50959762]
# S12 number = 4, samples = 5 sum in pes =4.248927590647803
# time vector (mus) = [ 235.825  235.85   235.875  235.9    235.925]
# energy vector (pes) = [ 0.59013921  0.98579078  1.09349994  0.860037    0.71946066]
# S12 number = 5, samples = 10 sum in pes =11.205834262369208
# time vector (mus) = [ 236.275  236.3    236.325  236.35   236.4    236.425  236.45   236.475
#   236.5    236.525]
# energy vector (pes) = [ 0.69178554  0.69232863  0.60873393  0.51315638  1.074349    1.82316089
#   1.80269906  1.76194672  1.47874737  0.75892675]
# S12 number = 6, samples = 8 sum in pes =7.129395145475098
# time vector (mus) = [ 236.65   236.675  236.7    236.725  236.75   236.775  236.8    236.825]
# energy vector (pes) = [ 0.73691927  0.81137567  1.18014117  0.80494448  1.04646727  1.03596018
#   0.83928926  0.67429784]
# S12 number = 7, samples = 5 sum in pes =4.8338519453450495
# time vector (mus) = [ 243.4    243.425  243.45   243.475  243.5  ]
# energy vector (pes) = [ 0.96004304  1.22844297  1.11950699  0.94211857  0.58374039]
# S12 number = 8, samples = 13 sum in pes =68.21024725294399
# time vector (mus) = [ 317.075  317.1    317.125  317.15   317.175  317.2    317.225  317.25
#   317.275  317.3    317.325  317.35   317.375]
# energy vector (pes) = [  2.47033499   6.91309034  10.87320584  12.16541969  10.73297097
#    7.69698071   4.86265878   3.29453758   2.48932935   2.16829538
#    1.9461595    1.58668514   1.01057898]
# S12 number = 9, samples = 7 sum in pes =5.252248144040165
# time vector (mus) = [ 412.375  412.4    412.425  412.45   412.475  412.5    412.525]
# energy vector (pes) = [ 0.59488359  0.81360295  0.83043686  0.81776578  0.78083536  0.81975433
#   0.59496928]
# S12 number = 10, samples = 7 sum in pes =16.797109800404385
# time vector (mus) = [ 574.3    574.325  574.35   574.375  574.4    574.425  574.45 ]
# energy vector (pes) = [ 0.51914695  1.90773392  3.05906776  4.04199544  3.68233469  2.398683
#   1.18814804]
# number of peaks = 1
# S12 number = 0, samples = 13 sum in pes =6166.949405571842
# time vector (mus) = [ 647.0625      648.0625      649.0625      650.0625      651.0625
#   652.0625      653.0625      654.0625      655.0625      656.0625
#   657.0625      658.0625      659.66212121]
# energy vector (pes) = [   88.34730532   137.84300883   296.37762305   428.35051558   792.37855285
#    912.35761442  1085.19108025   857.16270997   680.48719681   444.47287862
#    258.38122921   129.9873699     55.61232075]
# S2Si for peak number = 0
# sipm number = 863, energy = 47.84243202127983
# number of peaks = 1
# S12 number = 0, samples = 5 sum in pes =5.796387935761192
# time vector (mus) = [ 557.575  557.6    557.625  557.65   557.675]
# energy vector (pes) = [ 0.54641016  1.17712556  1.56881846  1.49121933  1.01281443]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =7008.257564386635
# time vector (mus) = [ 649.6875    650.7375    651.7375    652.7375    653.7375    654.7375
#   655.856875  656.734375]
# energy vector (pes) = [  169.38325832   769.70716424  1582.36079355  2309.46128331  1529.00983525
#    518.28629255   112.7993316     17.24960557]
# S2Si for peak number = 0
# sipm number = 1414, energy = 50.29661132805218
# sipm number = 1415, energy = 31.04909805737555
# sipm number = 1422, energy = 77.93247319665426
# sipm number = 1423, energy = 47.74527508491482
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =11.958377431510984
# time vector (mus) = [ 344.95   344.975  345.     345.025  345.05   345.075]
# energy vector (pes) = [ 1.11792117  2.36315354  3.15819635  2.89944165  1.8112952   0.60836952]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6348.650460898166
# time vector (mus) = [ 649.385625    650.3875      651.3875      652.3875      653.3875
#   654.3875      655.3875      656.37413793]
# energy vector (pes) = [  107.10550925   449.73881231  1230.9332785   1649.9727742   1702.62042009
#    889.84627107   258.43625369    59.99714179]
# S2Si for peak number = 0
# sipm number = 1084, energy = 39.23186802722085
# sipm number = 1085, energy = 47.105151091141366
# sipm number = 1344, energy = 46.812517649870905
# sipm number = 1345, energy = 78.5013980391451
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =14.789364490976778
# time vector (mus) = [ 525.65   525.675  525.7    525.725  525.75   525.775  525.8    525.825]
# energy vector (pes) = [ 0.50965187  1.69784001  2.9264128   3.2278478   2.87966718  2.00449387
#   0.98680565  0.5566453 ]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6304.209698921645
# time vector (mus) = [ 649.601875    650.6375      651.6375      652.6375      653.6375
#   654.6375      655.6375      656.69013158]
# energy vector (pes) = [  101.96551403   402.51498785  1034.75369524  1906.25468972  1495.62658507
#    913.41069449   328.87789991   120.80563262]
# S2Si for peak number = 0
# sipm number = 1114, energy = 50.29534502328988
# sipm number = 1115, energy = 41.1211216660183
# sipm number = 1122, energy = 49.77763669725786
# sipm number = 1123, energy = 68.08063789583298
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =5.3593911191684285
# time vector (mus) = [ 467.975  468.     468.025  468.05   468.075  468.1    468.125  468.15 ]
# energy vector (pes) = [ 0.54813606  0.54846638  0.59460418  0.75213442  0.79128578  0.8380333
#   0.71712973  0.56960126]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =3718.445981532587
# time vector (mus) = [ 648.673125    649.8375      650.8375      651.8375      652.8375
#   653.8375      654.8375      655.8375      656.75326087]
# energy vector (pes) = [  69.61570467  238.72882972  531.68199962  744.57946725  854.65966527
#   661.85733636  408.53438472  169.63762193   39.15097201]
# S2Si for peak number = 0
# sipm number = 411, energy = 39.60873198598129
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =13.961962143918015
# time vector (mus) = [ 596.975  597.     597.025  597.05   597.075  597.1    597.125]
# energy vector (pes) = [ 0.55657711  1.55674034  2.7482972   3.47183069  3.15954106  1.80077447
#   0.66820127]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6039.880904134721
# time vector (mus) = [ 649.8375      650.8375      651.8375      652.8375      653.8375
#   654.8375      655.71517857]
# energy vector (pes) = [  147.86698225   751.13793779  1785.1284847   1868.16030785  1098.4531479
#    327.07346016    62.06058349]
# S2Si for peak number = 0
# sipm number = 1546, energy = 33.49521990199378
# sipm number = 1547, energy = 32.460105366929994
# sipm number = 1554, energy = 85.5149066909422
# sipm number = 1555, energy = 96.34158933994189
# sipm number = 1562, energy = 39.21729954728248
# sipm number = 1563, energy = 34.21072638460362
# processing event number 30
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =7288.080235199927
# time vector (mus) = [ 649.560625  650.5625    651.5625    652.5625    653.5625    654.5625
#   655.5625    656.58875   657.4375  ]
# energy vector (pes) = [  170.5856949    492.09880009  1061.26556361  1489.10497482  1909.83164838
#   1430.04274256   604.29983424   121.01441483     9.83656178]
# S2Si for peak number = 0
# sipm number = 1542, energy = 45.47800806946205
# sipm number = 1550, energy = 97.59915009045947
# sipm number = 1551, energy = 61.39882302665886
# sipm number = 1558, energy = 30.962310484415987
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =12.2497282075937
# time vector (mus) = [ 561.3    561.325  561.35   561.375  561.4    561.425  561.45   561.475
#   561.5    561.525]
# energy vector (pes) = [ 0.85729907  1.41529812  1.76460662  1.62341429  1.54296145  1.38042328
#   1.02117069  1.12321662  0.91953613  0.60180194]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =7301.283403102783
# time vector (mus) = [ 649.4375  650.4625  651.4625  652.4625  653.4625  654.4625  655.4625
#   656.3625]
# energy vector (pes) = [   89.14830741   561.34616741  1434.78985687  2105.16000931  2019.08252225
#    838.40061173   202.76467741    50.59125072]
# S2Si for peak number = 0
# sipm number = 1110, energy = 49.93145801464659
# sipm number = 1118, energy = 94.60541874095463
# number of peaks = 2
# S12 number = 0, samples = 6 sum in pes =4.506143997694675
# time vector (mus) = [ 192.475  192.5    192.525  192.55   192.575  192.6  ]
# energy vector (pes) = [ 0.55954161  0.65613269  0.83094889  1.01549279  0.88397306  0.56005495]
# S12 number = 1, samples = 6 sum in pes =3.9518934732051534
# time vector (mus) = [ 555.     555.025  555.05   555.075  555.1    555.125]
# energy vector (pes) = [ 0.50051092  0.57603962  0.73880567  0.66221211  0.77550544  0.6988197 ]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6772.811043006544
# time vector (mus) = [ 649.6775   650.6875   651.6875   652.6875   653.6875   654.6875
#   655.70125  656.4875 ]
# energy vector (pes) = [  160.95977803   569.08934639  1445.18434972  2029.99618377  1547.04603242
#    804.59660458   201.39733911    14.54140899]
# S2Si for peak number = 0
# sipm number = 1352, energy = 41.63330110505202
# sipm number = 1353, energy = 38.12906388636148
# sipm number = 1360, energy = 95.47678861331866
# sipm number = 1361, energy = 41.15950139311992
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =7.26489468567726
# time vector (mus) = [ 533.675  533.7    533.725  533.75   533.825  533.85   533.875  533.9  ]
# energy vector (pes) = [ 0.69583935  1.23672105  1.37014216  1.1138208   0.53455857  0.80751314
#   0.84949895  0.65680066]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =4158.623309860096
# time vector (mus) = [ 649.328125  650.3375    651.3375    652.3375    653.3375    654.3375
#   655.345     656.25875 ]
# energy vector (pes) = [  122.05176276   482.86375547   731.73222598   991.6665729   1017.57652673
#    548.78643142   214.15845988    49.78757471]
# S2Si for peak number = 0
# sipm number = 1546, energy = 84.05424584318713
# sipm number = 1547, energy = 45.11154470453839
# sipm number = 1554, energy = 33.080621301775146
# number of peaks = 2
# S12 number = 0, samples = 6 sum in pes =4.931433831687378
# time vector (mus) = [ 174.2    174.225  174.25   174.275  174.3    174.325]
# energy vector (pes) = [ 0.63154264  0.890248    0.84253598  0.88005913  0.85991248  0.82713559]
# S12 number = 1, samples = 7 sum in pes =5.589115946720879
# time vector (mus) = [ 495.925  495.95   495.975  496.     496.025  496.05   496.125]
# energy vector (pes) = [ 0.89018822  0.97759328  0.84790686  0.83157149  0.94854146  0.58378715
#   0.50952749]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =4945.818306158517
# time vector (mus) = [ 649.558125    650.5625      651.5625      652.5625      653.5625
#   654.5625      655.5625      656.54276316]
# energy vector (pes) = [  169.12545374   496.70665136   938.31371142  1274.06734006  1067.80668948
#    612.95295654   278.84542728   108.00007627]
# S2Si for peak number = 0
# sipm number = 788, energy = 35.99312688063966
# sipm number = 796, energy = 40.50214573763775
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6.868540148382404
# time vector (mus) = [ 621.375  621.4    621.425  621.45   621.475  621.5    621.525]
# energy vector (pes) = [ 0.58388215  0.91492002  1.39336386  1.25270719  1.1832784   0.97491131
#   0.56547722]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =10034.341179126346
# time vector (mus) = [ 649.97625     650.9875      651.9875      652.9875      653.9875
#   655.018125    656.09107143]
# energy vector (pes) = [  269.82348125  1791.20274095  3323.22825122  3066.70359191  1342.8831351
#    207.48937644    33.01060226]
# S2Si for peak number = 0
# sipm number = 828, energy = 45.55249310949636
# sipm number = 829, energy = 109.71333346240496
# sipm number = 1156, energy = 82.56502474264526
# sipm number = 1157, energy = 141.41471179090357
# number of peaks = 3
# S12 number = 0, samples = 8 sum in pes =11.528622267089819
# time vector (mus) = [ 480.875  480.9    480.925  480.95   480.975  481.     481.025  481.05 ]
# energy vector (pes) = [ 0.9658433   1.55709056  1.68758932  2.17552033  2.03150938  1.40044231
#   1.11648875  0.59413832]
# S12 number = 1, samples = 8 sum in pes =147.08710379787942
# time vector (mus) = [ 575.025  575.05   575.075  575.1    575.125  575.15   575.175  575.2  ]
# energy vector (pes) = [  1.3835229    9.74752797  23.25639552  34.49184819  35.57717421
#   26.33677738  13.22682076   3.06703685]
# S12 number = 2, samples = 5 sum in pes =4.905093094254882
# time vector (mus) = [ 575.325  575.35   575.375  575.4    575.475]
# energy vector (pes) = [ 1.16539212  1.09723062  1.10885758  0.79252908  0.74108368]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4079.0871847503313
# time vector (mus) = [ 648.86375    649.9125     650.9125     651.9125     652.9125     653.9125
#   654.9125     655.9125     656.8766129]
# energy vector (pes) = [   77.31540285   237.53524659   627.70849932   787.07664087  1000.65595926
#    702.2516424    440.27264254   145.14594283    61.1252081 ]
# S2Si for peak number = 0
# sipm number = 701, energy = 42.68068698327617
# sipm number = 702, energy = 31.009451110265523
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =6.382670031606375
# time vector (mus) = [ 593.8    593.825  593.85   593.875  593.9    593.925]
# energy vector (pes) = [ 0.64386323  0.93898747  1.03099608  1.40323146  1.37416046  0.99143132]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6812.84497323704
# time vector (mus) = [ 650.1175      651.1375      652.1375      653.1375      654.1375
#   655.146875    656.55530303]
# energy vector (pes) = [  205.12060705  1090.42719513  2286.70473862  2057.71271533   924.28831173
#    186.05336984    62.53803553]
# S2Si for peak number = 0
# sipm number = 392, energy = 63.584073876860614
# sipm number = 400, energy = 63.17355538565306
# sipm number = 463, energy = 62.00717148756257
# sipm number = 471, energy = 47.04239907851641
# number of peaks = 1
# S12 number = 0, samples = 11 sum in pes =45.42585976865109
# time vector (mus) = [ 335.6    335.625  335.65   335.675  335.7    335.725  335.75   335.775
#   335.8    335.825  335.85 ]
# energy vector (pes) = [ 1.72577782  4.32478009  7.16656565  8.13639652  7.71023742  6.18240397
#   4.00545451  2.83098203  1.90202174  0.84991306  0.59132696]
# number of peaks = 1
# S12 number = 0, samples = 14 sum in pes =7405.417393999481
# time vector (mus) = [ 646.824375  648.0875    649.0875    650.0875    651.0875    652.0875
#   653.0875    654.0875    655.0875    656.0875    657.0875    658.200625
#   659.563125  660.875   ]
# energy vector (pes) = [   55.06407567   121.65178281   279.77221008   397.00155941   889.46409515
#   1136.96067103  1273.03073235  1339.91683958   955.94435414   534.21721621
#    246.59522499    99.3754179     67.51855703     8.90465765]
# S2Si for peak number = 0
# sipm number = 720, energy = 34.124031610860825
# sipm number = 783, energy = 30.846943150591493
# sipm number = 790, energy = 40.43594333992902
# sipm number = 791, energy = 54.85334999322366
# sipm number = 799, energy = 35.96712837935941
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =11.385797731190294
# time vector (mus) = [ 563.375  563.4    563.425  563.45   563.475  563.5    563.525  563.55 ]
# energy vector (pes) = [ 0.54220402  1.15091496  1.41195656  1.83061942  2.00157048  1.94964262
#   1.45383017  1.0450595 ]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7191.735050502932
# time vector (mus) = [ 649.7625      650.7625      651.7625      652.7625      653.7625
#   654.7625      655.61964286]
# energy vector (pes) = [  183.25284886   966.92723595  2234.47085462  2286.39264477  1136.05251689
#    305.50860323    79.13034618]
# S2Si for peak number = 0
# sipm number = 712, energy = 35.66769880602049
# sipm number = 775, energy = 55.21886868273977
# sipm number = 782, energy = 35.64707182648229
# sipm number = 783, energy = 105.46861296797957
# sipm number = 791, energy = 30.307589363925576
# processing event number 40
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =11.488167547673797
# time vector (mus) = [ 555.15   555.175  555.2    555.225  555.25   555.275  555.3    555.325]
# energy vector (pes) = [ 0.6363951   1.09941968  1.6838549   1.89761599  2.04726302  1.64374977
#   1.53290982  0.94695926]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6697.53552371823
# time vector (mus) = [ 650.0125  651.0125  652.0125  653.0125  654.0125  655.0125  656.02
#   656.975 ]
# energy vector (pes) = [  214.44512408   720.52483757  1709.24071772  2096.2163601   1266.16915606
#    517.35367158   151.2307411     22.3549155 ]
# S2Si for peak number = 0
# sipm number = 1194, energy = 74.21394404820953
# number of peaks = 12
# S12 number = 0, samples = 7 sum in pes =5.373442846465571
# time vector (mus) = [ 254.9    254.925  254.95   254.975  255.     255.025  255.05 ]
# energy vector (pes) = [ 0.50929121  0.8419219   0.95776751  1.12296619  0.6743128   0.71157658
#   0.55560666]
# S12 number = 1, samples = 8 sum in pes =6.941330936742581
# time vector (mus) = [ 470.725  470.75   470.775  470.8    470.825  470.85   470.875  470.9  ]
# energy vector (pes) = [ 0.55411886  1.29960801  1.30052794  1.20496813  0.78639679  0.50235822
#   0.73007438  0.56327863]
# S12 number = 2, samples = 8 sum in pes =7.49636480888377
# time vector (mus) = [ 471.025  471.05   471.075  471.1    471.125  471.15   471.175  471.2  ]
# energy vector (pes) = [ 0.75402878  1.28332219  1.48145063  1.28566225  0.75563884  0.72382483
#   0.62109609  0.5913412 ]
# S12 number = 3, samples = 16 sum in pes =17.91798704156109
# time vector (mus) = [ 471.7    471.725  471.75   471.775  471.8    471.825  471.85   471.875
#   471.9    471.925  471.95   471.975  472.     472.025  472.1    472.125]
# energy vector (pes) = [ 0.70129136  0.69421063  1.02623879  0.92081154  0.69207622  0.76486462
#   1.55975494  2.30383985  2.3968916   2.00452547  1.48101275  0.91470567
#   0.61552286  0.51509385  0.64810063  0.67904627]
# S12 number = 4, samples = 10 sum in pes =8.62173914338167
# time vector (mus) = [ 472.85   472.875  472.9    472.925  472.95   472.975  473.     473.025
#   473.05   473.075]
# energy vector (pes) = [ 0.56276641  0.67311329  0.66873822  0.57496589  0.75925332  0.83046203
#   0.94063123  1.43070388  1.28882822  0.89227664]
# S12 number = 5, samples = 14 sum in pes =15.572785307261961
# time vector (mus) = [ 473.2    473.225  473.3    473.325  473.35   473.375  473.4    473.425
#   473.45   473.475  473.575  473.6    473.625  473.65 ]
# energy vector (pes) = [ 0.57229134  0.56689257  0.76279268  1.62159802  1.8626457   2.02155837
#   1.80328328  0.90769113  1.03683335  0.59498966  0.90208343  1.11917848
#   1.22106044  0.57988685]
# S12 number = 6, samples = 16 sum in pes =17.2998709374456
# time vector (mus) = [ 481.225  481.25   481.275  481.3    481.325  481.4    481.425  481.45
#   481.525  481.575  481.6    481.625  481.65   481.675  481.7    481.725]
# energy vector (pes) = [ 1.16828139  0.89880507  0.58288271  0.64062836  0.73031019  0.68051509
#   0.63313311  0.5393626   0.55185219  0.67677329  1.2388071   1.88886528
#   1.66119576  2.00589851  1.89424061  1.50831966]
# S12 number = 7, samples = 7 sum in pes =5.36771933242826
# time vector (mus) = [ 482.15   482.225  482.275  482.3    482.325  482.35   482.375]
# energy vector (pes) = [ 0.67660282  0.52727763  0.85797393  1.00005005  1.027089    0.76797471
#   0.51075119]
# S12 number = 8, samples = 5 sum in pes =3.6525218406224185
# time vector (mus) = [ 489.45   489.55   489.575  489.6    489.625]
# energy vector (pes) = [ 0.50341221  0.69380049  0.95729384  0.91100995  0.58700534]
# S12 number = 9, samples = 9 sum in pes =6.183755670879801
# time vector (mus) = [ 510.075  510.1    510.125  510.15   510.175  510.2    510.275  510.3
#   510.325]
# energy vector (pes) = [ 0.68677419  0.72527524  0.686255    0.8409377   0.69011122  0.52177574
#   0.73526776  0.66558768  0.63177114]
# S12 number = 10, samples = 7 sum in pes =4.835993674601042
# time vector (mus) = [ 614.55   614.575  614.6    614.625  614.725  614.75   614.775]
# energy vector (pes) = [ 0.66818338  0.67397969  0.53847487  0.57496569  0.7322479   0.87693052
#   0.77121163]
# S12 number = 11, samples = 6 sum in pes =4.870980582696246
# time vector (mus) = [ 626.275  626.3    626.325  626.35   626.375  626.4  ]
# energy vector (pes) = [ 0.7459655   0.93896669  0.86220637  0.85895319  0.88923801  0.57565082]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =8578.898628704716
# time vector (mus) = [ 650.124375  651.1625    652.1625    653.1625    654.1625    655.1625
#   656.34375 ]
# energy vector (pes) = [  335.84830822  1859.37899779  2863.44927685  2118.03077639  1159.5753278
#    232.09576647    10.52017517]
# S2Si for peak number = 0
# sipm number = 408, energy = 48.80109161500506
# sipm number = 416, energy = 169.7976775048128
# sipm number = 417, energy = 33.961671844002154
# sipm number = 424, energy = 30.275919840580528
# sipm number = 487, energy = 32.875289847766915
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6413.682204780804
# time vector (mus) = [ 649.6025      650.6625      651.6625      652.6625      653.6625
#   654.6625      655.6625      656.60096154]
# energy vector (pes) = [  158.04727627   493.56996365  1209.97888155  1885.61086949  1416.22210065
#    900.97473045   292.81660582    56.4617769 ]
# S2Si for peak number = 0
# sipm number = 755, energy = 49.520655689174475
# sipm number = 763, energy = 66.74525454455895
# number of peaks = 2
# S12 number = 0, samples = 5 sum in pes =5.632977531438616
# time vector (mus) = [ 581.975  582.     582.025  582.05   582.075]
# energy vector (pes) = [ 0.5334936   1.14963201  1.37478494  1.44709774  1.12796923]
# S12 number = 1, samples = 6 sum in pes =4.525086808418117
# time vector (mus) = [ 582.2    582.225  582.25   582.275  582.3    582.325]
# energy vector (pes) = [ 0.61719614  0.77589768  1.06399552  0.9065128   0.62426742  0.53721725]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6993.324053543332
# time vector (mus) = [ 649.6875     650.6875     651.6875     652.6875     653.6875     654.6875
#   655.7765625]
# energy vector (pes) = [  142.78376723   814.71100105  1904.69543139  2221.88150282  1524.60719298
#    353.98688181    30.65827625]
# S2Si for peak number = 0
# sipm number = 1558, energy = 37.67412445699413
# sipm number = 1559, energy = 104.59500191239715
# sipm number = 1566, energy = 33.65790518406541
# sipm number = 1567, energy = 71.30863231124958
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7.106828336493063
# time vector (mus) = [ 574.1    574.125  574.15   574.175  574.2    574.225  574.25 ]
# energy vector (pes) = [ 0.59809708  1.17619737  1.56569367  1.59454851  1.06154711  0.54191313
#   0.56883146]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6718.253773352064
# time vector (mus) = [ 650.0875      651.0875      652.0875      653.0875      654.0875
#   655.0875      655.98235294]
# energy vector (pes) = [  227.7829484    793.67423177  1820.25371235  2169.18946733  1295.60872427
#    382.27664981    29.46803943]
# S2Si for peak number = 0
# sipm number = 1541, energy = 44.067936911782965
# sipm number = 1542, energy = 53.2728714475162
# sipm number = 1549, energy = 47.48518641989913
# sipm number = 1550, energy = 52.29689980559042
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =7.401816001056917
# time vector (mus) = [ 545.15   545.175  545.2    545.225  545.25   545.275  545.3    545.325
#   545.35   545.375]
# energy vector (pes) = [ 0.59502994  0.86427261  0.74357282  0.74381717  0.76125352  0.89597116
#   0.84163262  0.81625242  0.6091659   0.53084783]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =4864.17975253716
# time vector (mus) = [ 649.4625      650.4625      651.4625      652.4625      653.4625
#   654.4625      655.4625      656.25869565]
# energy vector (pes) = [   95.17166839   348.41888154  1058.7846863   1405.71910719  1155.801677
#    561.90262252   187.05170381    51.32940579]
# S2Si for peak number = 0
# sipm number = 847, energy = 82.9636092465353
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =10.09340310669289
# time vector (mus) = [ 526.675  526.7    526.725  526.75   526.775  526.8    526.825  526.925
#   526.95 ]
# energy vector (pes) = [ 0.74251787  1.4594205   1.7606143   1.8862901   1.62855301  0.80675578
#   0.56532935  0.60283898  0.64108321]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =5975.570424600603
# time vector (mus) = [ 649.525   650.6375  651.6375  652.6375  653.6375  654.6375  655.6375
#   656.9375]
# energy vector (pes) = [  102.81529809   627.76340898  1349.04937898  1640.49434772  1297.31604091
#    725.78619553   184.2432248     48.10252959]
# S2Si for peak number = 0
# sipm number = 1174, energy = 55.4434369322067
# sipm number = 1182, energy = 43.2001770756882
# number of peaks = 2
# S12 number = 0, samples = 6 sum in pes =5.654818348964059
# time vector (mus) = [ 460.5    460.525  460.55   460.575  460.65   460.675]
# energy vector (pes) = [ 0.72264774  1.21122521  1.49769565  1.08315444  0.59216393  0.54793138]
# S12 number = 1, samples = 6 sum in pes =10.674834871068995
# time vector (mus) = [ 461.175  461.2    461.225  461.25   461.275  461.3  ]
# energy vector (pes) = [ 0.605038    1.73847248  2.68398373  2.76164889  1.97077611  0.91491566]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4430.292820209647
# time vector (mus) = [ 648.766875  649.8375    650.8375    651.8375    652.8375    653.8375
#   654.8375    655.8375    656.7     ]
# energy vector (pes) = [  82.44004317  228.10355725  508.47323074  863.58968023  952.99174812
#   874.38023676  559.48201937  286.32127503   74.51102954]
# S2Si for peak number = 0
# sipm number = 1033, energy = 30.002835002835
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7.113249126965148
# time vector (mus) = [ 472.475  472.5    472.525  472.55   472.575  472.6    472.625]
# energy vector (pes) = [ 0.5342748   0.66342393  0.83409647  1.34972818  1.59836893  1.35214781
#   0.781209  ]
# number of peaks = 1
# S12 number = 0, samples = 10 sum in pes =5279.021924324302
# time vector (mus) = [ 648.95      649.9875    650.9875    651.9875    652.9875    653.9875
#   654.9875    655.9875    657.086875  659.1375  ]
# energy vector (pes) = [   98.38027766   263.84474125   707.56343994  1145.54418914  1132.763227
#    972.55482548   601.21450254   267.48187615    87.37986861     2.29497654]
# S2Si for peak number = 0
# sipm number = 1133, energy = 34.592256270364125
# sipm number = 1141, energy = 69.3056252605075
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6.175957853563789
# time vector (mus) = [ 508.825  508.85   508.875  508.9    508.925  508.95   509.05 ]
# energy vector (pes) = [ 0.52428789  0.83990943  1.09666284  1.1478324   1.14345329  0.88749712
#   0.53631488]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =4901.8556748416695
# time vector (mus) = [ 649.588125  650.6875    651.6875    652.6875    653.6875    654.6875
#   655.6875    656.7325    657.475   ]
# ...
#    479.68834393    96.64302369]
# S2Si for peak number = 0
# sipm number = 536, energy = 48.80550933102828
# sipm number = 544, energy = 54.007896303094455
# number of peaks = 1
# S12 number = 0, samples = 14 sum in pes =17.72572033619716
# time vector (mus) = [ 504.7    504.725  504.75   504.775  504.8    504.825  504.85   504.875
#   504.925  504.95   504.975  505.     505.025  505.05 ]
# energy vector (pes) = [ 0.76752317  1.00252643  1.74425857  2.56193143  2.64737036  2.36847147
#   1.37231598  0.78400427  0.50506682  0.74879868  0.64113931  1.04061955
#   0.82677568  0.71491865]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =5290.3175540304
# time vector (mus) = [ 648.7425    649.8125    650.8125    651.8125    652.8125    653.8125
#   654.8125    655.829375  656.73    ]
# energy vector (pes) = [   81.89150971   210.60669898   613.30703933  1121.87796175  1420.55148398
#   1072.10887244   558.16430599   171.6345877     40.17509415]
# S2Si for peak number = 0
# sipm number = 1089, energy = 57.089330287663685
# sipm number = 1090, energy = 52.04525754753518
# sipm number = 1098, energy = 30.704023251536256
# number of peaks = 19
# S12 number = 0, samples = 6 sum in pes =5.554254571930141
# time vector (mus) = [ 127.775  127.8    127.825  127.85   127.875  127.9  ]
# energy vector (pes) = [ 0.63344236  0.74761287  1.03632723  1.32241311  1.2636881   0.5507709 ]
# S12 number = 1, samples = 9 sum in pes =18.465535408671293
# time vector (mus) = [ 135.35   135.375  135.4    135.425  135.45   135.475  135.5    135.525
#   135.55 ]
# energy vector (pes) = [ 1.21365063  1.2152004   1.34065678  2.64240106  3.44476539  3.32911556
#   2.68690527  1.37095403  1.22188628]
# S12 number = 2, samples = 13 sum in pes =23.266802039810145
# time vector (mus) = [ 135.675  135.7    135.725  135.75   135.775  135.8    135.825  135.85
#   135.9    135.925  135.95   135.975  136.   ]
# energy vector (pes) = [ 1.34949803  1.81264074  2.0667981   1.85996636  2.38611421  1.30319559
#   2.40603894  1.33641874  1.05219842  1.68395211  1.85345054  2.91809811
#   1.23843216]
# S12 number = 3, samples = 16 sum in pes =34.1124097937398
# time vector (mus) = [ 136.15   136.175  136.2    136.225  136.25   136.275  136.3    136.325
#   136.35   136.375  136.4    136.425  136.45   136.475  136.5    136.525]
# energy vector (pes) = [ 1.11116657  1.57390653  1.61793763  2.72049898  1.94181404  3.31090156
#   3.01877365  2.44861817  1.54213793  2.39661628  2.18898624  1.5736305
#   2.91288828  3.09224911  1.43458502  1.2276993 ]
# S12 number = 4, samples = 16 sum in pes =20.098762986797773
# time vector (mus) = [ 136.65   136.675  136.7    136.725  136.75   136.775  136.8    136.85
#   136.875  136.9    136.925  136.95   137.05   137.075  137.125  137.15 ]
# energy vector (pes) = [ 1.27599423  1.57892111  1.54220243  1.27886286  1.26691723  2.35071036
#   1.06792179  0.93029302  1.22940661  1.35012287  1.17290642  0.93577927
#   0.92572182  0.85416809  1.13130957  1.20752531]
# S12 number = 5, samples = 10 sum in pes =12.367007775165025
# time vector (mus) = [ 137.275  137.3    137.325  137.35   137.375  137.4    137.475  137.5
#   137.525  137.55 ]
# energy vector (pes) = [ 0.51172084  1.28540835  2.1557232   1.95824583  1.80462038  0.8208432
#   0.76587555  1.27445716  1.19105656  0.59905672]
# S12 number = 6, samples = 6 sum in pes =4.069255014030162
# time vector (mus) = [ 138.125  138.15   138.225  138.25   138.275  138.3  ]
# energy vector (pes) = [ 0.67847124  0.60671641  0.87202379  0.72708365  0.68255521  0.50240472]
# S12 number = 7, samples = 8 sum in pes =9.095508485459328
# time vector (mus) = [ 138.775  138.8    138.825  138.85   138.875  138.9    138.925  138.95 ]
# energy vector (pes) = [ 1.04252744  1.46087483  1.32030273  0.77994338  0.74096704  1.26663091
#   1.33948791  1.14477424]
# S12 number = 8, samples = 7 sum in pes =4.988508881594727
# time vector (mus) = [ 289.625  289.7    289.725  289.75   289.775  289.8    289.825]
# energy vector (pes) = [ 0.50239725  0.52447818  0.54326192  0.87170575  0.98897502  0.92273491
#   0.63495584]
# S12 number = 9, samples = 5 sum in pes =3.684990861101105
# time vector (mus) = [ 307.4    307.425  307.45   307.475  307.5  ]
# energy vector (pes) = [ 0.80462728  0.95679187  0.83473833  0.56307642  0.52575696]
# S12 number = 10, samples = 18 sum in pes =17.196108408050137
# time vector (mus) = [ 309.925  309.95   309.975  310.     310.025  310.05   310.075  310.15
#   310.175  310.2    310.225  310.25   310.275  310.3    310.325  310.35
#   310.375  310.4  ]
# energy vector (pes) = [ 0.54923543  0.77129831  0.88007025  1.09814916  0.80130446  0.87359202
#   0.82704428  0.59272497  0.99965988  1.35284891  1.71367951  1.80520624
#   1.40510559  0.5943337   0.66938954  0.85658068  0.85586345  0.55002201]
# S12 number = 11, samples = 18 sum in pes =20.589726254518155
# time vector (mus) = [ 310.55   310.575  310.6    310.625  310.65   310.675  310.7    310.725
#   310.75   310.775  310.8    310.825  310.875  310.925  310.95   310.975
#   311.     311.025]
# energy vector (pes) = [ 0.85911875  1.12658559  1.4100262   1.3703567   1.08879576  1.48744728
#   1.18714736  1.08111852  0.9973506   1.0051944   1.05009443  1.16319097
#   0.55796777  1.14463142  1.47859545  1.6340142   1.26281518  0.68527568]
# S12 number = 12, samples = 12 sum in pes =15.405372618387824
# time vector (mus) = [ 319.15   319.175  319.2    319.225  319.25   319.275  319.325  319.35
#   319.375  319.4    319.425  319.45 ]
# energy vector (pes) = [ 1.35383139  1.55239245  1.42388438  0.62777423  1.01618988  0.59265685
#   0.79284797  1.67611973  2.07694071  1.98950712  1.38616132  0.91706659]
# S12 number = 13, samples = 5 sum in pes =3.8583632970443147
# time vector (mus) = [ 320.45   320.475  320.5    320.525  320.6  ]
# energy vector (pes) = [ 0.56600005  0.87395935  0.8353156   0.99631827  0.58677003]
# S12 number = 14, samples = 6 sum in pes =4.339200652903149
# time vector (mus) = [ 326.4    326.425  326.45   326.475  326.5    326.6  ]
# energy vector (pes) = [ 0.73084874  0.94093457  0.8654866   0.70261664  0.58231327  0.51700083]
# S12 number = 15, samples = 6 sum in pes =3.779599301768557
# time vector (mus) = [ 339.4    339.425  339.45   339.475  339.5    339.525]
# energy vector (pes) = [ 0.69714572  0.53408772  0.56178236  0.69869729  0.64438542  0.64350078]
# S12 number = 16, samples = 10 sum in pes =7.131826562371596
# time vector (mus) = [ 550.7    550.725  550.75   550.775  550.8    550.825  550.85   550.875
#   550.9    550.925]
# energy vector (pes) = [ 0.50490311  0.83113012  0.95627472  1.01904094  0.75058652  0.54864412
#   0.61588333  0.73520409  0.60714385  0.56301577]
# S12 number = 17, samples = 6 sum in pes =7.024769361514405
# time vector (mus) = [ 573.875  573.9    573.925  573.95   573.975  574.   ]
# energy vector (pes) = [ 0.74750757  1.22386301  1.43727952  1.4185972   1.3015259   0.89599617]
# S12 number = 18, samples = 7 sum in pes =4.4140308868555875
# time vector (mus) = [ 628.4    628.425  628.45   628.475  628.525  628.55   628.575]
# energy vector (pes) = [ 0.52724542  0.85249838  0.72802567  0.52601142  0.59238216  0.67001721
#   0.51785063]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =7583.670809386334
# time vector (mus) = [ 649.984375  651.0125    652.0125    653.0125    654.0125    655.0125
#   655.7     ]
# energy vector (pes) = [  189.12729528   990.68078447  2076.1925185   2440.36829451  1435.34348091
#    411.88097393    40.07746179]
# S2Si for peak number = 0
# sipm number = 802, energy = 59.02827799784775
# sipm number = 803, energy = 43.76378107753975
# sipm number = 810, energy = 81.71316647345778
# sipm number = 811, energy = 49.77757230388267
# processing event number 150
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =222.8772709982715
# time vector (mus) = [ 422.75   422.775  422.8    422.825  422.85   422.875  422.9    422.925]
# energy vector (pes) = [  1.93839539  13.69308679  34.59921423  52.61818028  54.98312782
#   41.03106094  20.52759592   3.48660963]
# number of peaks = 1
# S12 number = 0, samples = 7 sum in pes =6552.707916129718
# time vector (mus) = [ 649.775   650.7875  651.7875  652.7875  653.7875  654.7875  655.5125]
# energy vector (pes) = [  137.07263269   821.83147189  1786.2975273   2074.89935341  1221.44196266
#    449.97764327    61.18732492]
# S2Si for peak number = 0
# sipm number = 769, energy = 38.99641562960555
# sipm number = 770, energy = 43.070104370636585
# sipm number = 777, energy = 68.49290407753007
# sipm number = 778, energy = 65.83447324769769
# number of peaks = 2
# S12 number = 0, samples = 7 sum in pes =77.9555035632158
# time vector (mus) = [ 104.6    104.625  104.65   104.675  104.7    104.725  104.75 ]
# energy vector (pes) = [  2.3611021    8.73594645  16.63414537  19.85759692  17.18960997
#   10.20560167   2.97150109]
# S12 number = 1, samples = 7 sum in pes =8.650909855873229
# time vector (mus) = [ 543.45   543.475  543.5    543.525  543.55   543.575  543.6  ]
# energy vector (pes) = [ 0.8481181   1.3947828   1.5398158   1.55816323  1.4097863   1.12212858
#   0.77811505]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =4702.314852389185
# time vector (mus) = [ 648.995       650.0125      651.0125      652.0125      653.0125
#   654.0125      655.0125      656.03382353]
# energy vector (pes) = [   94.35927019   337.15637426   772.39357112  1355.77524735  1204.50282989
#    601.77546321   271.74708703    64.60500935]
# S2Si for peak number = 0
# sipm number = 110, energy = 37.64020876422816
# sipm number = 111, energy = 54.26167029224673
# sipm number = 119, energy = 45.32470549700832
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =13.92896249383346
# time vector (mus) = [ 525.775  525.8    525.825  525.85   525.875  525.9    525.925  525.95 ]
# energy vector (pes) = [ 0.82805503  1.35384796  1.884193    2.45726282  2.4740907   2.23762641
#   1.69396684  0.99991973]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =6260.373767391073
# time vector (mus) = [ 649.618125  650.6875    651.6875    652.6875    653.6875    654.6875
#   655.6875    656.6875    657.90625 ]
# energy vector (pes) = [  115.02853115   465.32129162   988.39101866  1380.11112628  1506.85753767
#   1094.95775529   513.57738115   163.58970233    32.53942324]
# S2Si for peak number = 0
# sipm number = 753, energy = 37.70309466779965
# sipm number = 761, energy = 75.17342671594467
# sipm number = 762, energy = 30.397113099966287
# number of peaks = 0
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6133.283474538034
# time vector (mus) = [ 649.649375  650.6875    651.6875    652.6875    653.6875    654.6875
#   655.755     657.0675  ]
# energy vector (pes) = [  177.52533972   528.86589739  1475.08482349  1919.76374385  1314.89966251
#    581.93534844   118.7194115     16.48924764]
# S2Si for peak number = 0
# sipm number = 681, energy = 37.153620532875706
# sipm number = 682, energy = 50.38930828585845
# number of peaks = 1
# S12 number = 0, samples = 5 sum in pes =5.132888548930286
# time vector (mus) = [ 604.95   604.975  605.     605.025  605.05 ]
# energy vector (pes) = [ 0.90537974  1.24593157  1.34803504  1.12353467  0.51000753]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =8804.89187588393
# time vector (mus) = [ 649.8875   650.8875   651.8875   652.8875   653.8875   654.8875
#   655.89625  656.81875]
# energy vector (pes) = [  197.10120613  1290.24553318  2684.72266346  1818.33847441  1527.30387573
#   1004.23628812   265.92915188    17.01468297]
# S2Si for peak number = 0
# sipm number = 819, energy = 38.02294197031039
# sipm number = 826, energy = 61.25425210882304
# sipm number = 827, energy = 168.2272583601101
# number of peaks = 1
# S12 number = 0, samples = 6 sum in pes =6.109509557524209
# time vector (mus) = [ 581.275  581.3    581.325  581.35   581.375  581.4  ]
# energy vector (pes) = [ 0.52579343  1.02856497  1.52806338  1.3789847   1.0902547   0.55784838]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =5589.497385688448
# time vector (mus) = [ 649.63875   650.6625    651.6625    652.6625    653.6625    654.6625
#   655.674375  656.825   ]
# energy vector (pes) = [  149.38683677   640.9200554   1327.1201888   1740.48574705  1125.48278196
#    491.97062376   109.33688018     4.79427177]
# S2Si for peak number = 0
# sipm number = 1685, energy = 32.36580778871467
# sipm number = 1693, energy = 86.82508620138194
# sipm number = 1694, energy = 40.4520716677999
# number of peaks = 1
# S12 number = 0, samples = 5 sum in pes =11.268729910954598
# time vector (mus) = [ 532.     532.025  532.05   532.075  532.1  ]
# energy vector (pes) = [ 1.47854051  2.69414848  3.05197528  2.60867137  1.43539428]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =6526.193604208974
# time vector (mus) = [ 648.721875    649.7875      650.7875      651.7875      652.7875
#   653.7875      654.7875      655.861875    657.40147059]
# energy vector (pes) = [   76.32820109   186.24163262   780.68513492  1596.32857366  1921.16268081
#   1270.38841127   501.75371959   166.54684985    26.75840041]
# S2Si for peak number = 0
# sipm number = 707, energy = 56.09823993116625
# sipm number = 708, energy = 69.0621082479474
# sipm number = 709, energy = 30.194099612144143
# sipm number = 716, energy = 44.2969241927899
# number of peaks = 3
# S12 number = 0, samples = 8 sum in pes =64.21141893605405
# time vector (mus) = [ 1.125  1.15   1.175  1.2    1.225  1.25   1.275  1.3  ]
# energy vector (pes) = [  3.33404965   9.25572407  14.44854255  15.48559913  12.04639652
#    6.61289334   2.27098824   0.75722543]
# S12 number = 1, samples = 5 sum in pes =2.7786873278100654
# time vector (mus) = [ 1.425  1.45   1.475  1.5    1.525]
# energy vector (pes) = [ 0.53653905  0.510772    0.67904186  0.52595838  0.52637604]
# S12 number = 2, samples = 6 sum in pes =5.331649615004856
# time vector (mus) = [ 527.875  527.9    527.925  527.95   527.975  528.   ]
# energy vector (pes) = [ 0.52806742  0.91857402  1.18507781  1.15791704  0.9910063   0.55100704]
# number of peaks = 1
# S12 number = 0, samples = 9 sum in pes =5629.598819230748
# time vector (mus) = [ 648.9325    650.0125    651.0125    652.0125    653.0125    654.0125
#   655.0125    656.029375  656.9625  ]
# energy vector (pes) = [   78.00986838   263.68829952   817.48548805  1397.92763156  1488.38895843
#   1033.31996524   414.97105683   125.5966972     10.21085402]
# S2Si for peak number = 0
# sipm number = 1456, energy = 58.640278936367636
# sipm number = 1519, energy = 30.44796669343867
# sipm number = 1527, energy = 70.89956374545787
# number of peaks = 1
# S12 number = 0, samples = 5 sum in pes =6.956926322791319
# time vector (mus) = [ 540.75   540.775  540.8    540.825  540.85 ]
# energy vector (pes) = [ 1.0810465   1.81569495  1.96326832  1.33977893  0.75713762]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =3770.3609459304653
# time vector (mus) = [ 649.31125     650.3375      651.3375      652.3375      653.3375
#   654.3375      655.3375      656.43365385]
# energy vector (pes) = [  91.86976625  395.03600665  639.7056635   950.63831981  903.65273999
#   566.11715858  165.09379386   58.24749729]
# S2Si for peak number = 0
# sipm number = 1283, energy = 46.818200544195804
# sipm number = 1284, energy = 31.005694120337875
# number of peaks = 1
# S12 number = 0, samples = 12 sum in pes =11.576078274977796
# time vector (mus) = [ 558.2    558.225  558.25   558.275  558.3    558.325  558.35   558.375
#   558.4    558.425  558.45   558.475]
# energy vector (pes) = [ 0.60467732  1.25959711  1.37043735  1.25156524  1.16326159  0.99597818
#   0.83816333  0.75703737  0.86984037  1.05046946  0.85624996  0.558801  ]
# number of peaks = 1
# S12 number = 0, samples = 8 sum in pes =6878.29049814957
# time vector (mus) = [ 649.5375    650.5375    651.5375    652.5375    653.5375    654.5375
#   655.545     656.696875]
# energy vector (pes) = [  168.17788557   651.94024094  1465.09885173  2210.42278257  1554.36614922
#    608.24515449   207.15562595    12.88380769]
# S2Si for peak number = 0
# sipm number = 355, energy = 67.76086750114729
# sipm number = 356, energy = 34.79274391598023
# sipm number = 363, energy = 61.737622505014066
# sipm number = 364, energy = 52.7882851944763
# run 160 events in 79.48270320892334 s event/s = 0.4967668950557709
